# %% [markdown]
# Overview...
#
# This Python notebook demonsrates the _sliding window_ version of word count on a stream, based on a homework assignment in Konstantin's COMP 372 class. He's using this as a motivating example to understand imperative vs. functional programming (thinking in immutable terms).
#
# This example is even interesting as a mutable example. In my solution, I have tried to avoid any Python tricks. We do use generators, which is Python's way of supporting _inifinitary_ thinking. The real work is in the `wc_on_generator()` method that processes the indefinite stream and--in the process--produces i a new infintary stream, where each stream is a dictionary (map) of the word counts within a given window.
#
# This code will be packaged as a standalone Python program, but I like working things out in notebooks first and then turning them into more polished programs later. This can handle any stream. The user is prompted for `window_size` (the last number of lines to count words), `windows` (number of items to "take" from the resulting stream), and `min_count` (the minimum count to show, of great interest in digital humanities to avoid infrequent words).
#
# It's not as beautiful as Scala but tries to be beautiful/idiomatic in a Pythonic sense. Enjoy!

# %%
from collections import deque
import urllib
import re

# %% [markdown]
# - We use a deque, which supports efficient access at either end of the deque. It is a built-in collections type in Python.
# - urllib is only here to fetch some text from Project Gutenberg
# - re is for regex and splitting the text into a stream of words

# %%
resource = urllib.request.urlopen("http://www.gutenberg.org/files/1524/1524-0.txt")
text = resource.read().decode("utf-8")
text = text[2000:] # skip unwanted header info (about 2000 chars) on Gutenberg's text.

# %%
word_pattern = re.compile("\w+")
words = re.findall(word_pattern, text)

# %% [markdown]
# We are mutable in two ways:
# - adding and removing items from the LRU cache (LRU here means least recent word within window)
# - word counts for the current window

# %%
def wc_on_generator(word_generator, window_size):
    lru_word_cache = deque() # using deque but can also use fixed list/array in Python (next time)
    wc = {}
    for word in word_generator:
        wc[word] = wc.get(word, 0) + 1
        lru_word_cache.append(word)
        if len(lru_word_cache) > window_size:
            lru_item = lru_word_cache.popleft()
            wc[lru_item] = wc.get(lru_item, 1) - 1
        yield wc

# %%
def show_counts(wc, min_count = 1):
    sorted_keys = list(wc.keys())
    sorted_keys.sort()
    report = ", ".join(["%s=%d" % (word, wc[word]) for word in sorted_keys if wc[word] >= min_count] )
    if len(report):
        return report
    else:
        return "No word occurred more than %d times in this window." % min_count

# %%
window_size = int(input("Window Size? "))
windows = int(input("Windows? "))
min_count = max(int(input("Minimum Count to Show? ")), 0)
wc_generator = wc_on_generator(words, window_size)
for window in range(0, windows):
    print("%d:" % window, show_counts(next(wc_generator), min_count))
    print()
# Out:
# Window Size? 100
# Windows? 150
# Minimum Count to Show? 2
# 0: No word occurred more than 2 times in this window.
#
# 1: No word occurred more than 2 times in this window.
#
# 2: No word occurred more than 2 times in this window.
#
# 3: No word occurred more than 2 times in this window.
#
# 4: No word occurred more than 2 times in this window.
#
# 5: No word occurred more than 2 times in this window.
#
# 6: No word occurred more than 2 times in this window.
#
# 7: Courtier=2
#
# 8: Courtier=2
#
# 9: Courtier=3
#
# 10: Courtier=3
#
# 11: Courtier=4
#
# 12: Courtier=4
#
# 13: Courtier=4
#
# 14: Courtier=4
#
# 15: Courtier=4, Officer=2
#
# 16: Courtier=4, Officer=2
#
# 17: Courtier=4, Officer=2
#
# 18: Courtier=4, Officer=2
#
# 19: Courtier=4, Officer=2
#
# 20: Courtier=5, Officer=2
#
# 21: Courtier=5, Officer=2
#
# 22: Courtier=5, Officer=2
#
# 23: Courtier=5, Officer=2
#
# 24: Courtier=5, Officer=2
#
# 25: Courtier=5, Officer=2
#
# 26: Courtier=5, Officer=2
#
# 27: Courtier=5, Officer=2
#
# 28: Courtier=6, Officer=2
#
# 29: A=2, Courtier=6, Officer=2
#
# 30: A=2, Courtier=6, Officer=2
#
# 31: A=2, Courtier=6, Officer=2
#
# 32: A=2, Courtier=6, Officer=2
#
# 33: A=2, Courtier=6, Officer=2
#
# 34: A=2, Courtier=6, Officer=2
#
# 35: A=3, Courtier=6, Officer=2
#
# 36: A=3, Courtier=6, Officer=2
#
# 37: A=3, Courtier=6, Officer=2
#
# 38: A=3, Courtier=6, Officer=2
#
# 39: A=3, Courtier=6, Officer=2
#
# 40: A=3, Courtier=6, Officer=2
#
# 41: A=3, Courtier=6, Officer=2
#
# 42: A=3, Courtier=6, Officer=2
#
# 43: A=3, Courtier=6, Officer=2
#
# 44: A=3, Courtier=6, Officer=2
#
# 45: A=3, Courtier=6, Officer=2
#
# 46: A=3, Courtier=6, Officer=2
#
# 47: A=3, Courtier=6, Officer=2
#
# 48: A=3, Courtier=6, Officer=2
#
# 49: A=3, Courtier=6, Officer=2
#
# 50: A=3, Courtier=6, Officer=2
#
# 51: A=3, Courtier=6, Officer=2, SCENE=2
#
# 52: A=3, Courtier=6, I=2, Officer=2, SCENE=2
#
# 53: A=3, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 54: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 55: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 56: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 57: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 58: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 59: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 60: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2
#
# 61: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 62: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 63: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 64: A=4, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 65: A=4, BARNARDO=2, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 66: A=4, BARNARDO=2, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 67: A=4, BARNARDO=2, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 68: A=4, BARNARDO=2, Courtier=6, Elsinore=2, I=2, Officer=2, SCENE=2, and=2
#
# 69: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=2
#
# 70: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=2
#
# 71: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=2
#
# 72: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=2
#
# 73: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=2
#
# 74: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3
#
# 75: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3
#
# 76: A=4, BARNARDO=2, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3
#
# 77: A=4, BARNARDO=3, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3
#
# 78: A=4, BARNARDO=3, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3
#
# 79: A=4, BARNARDO=3, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3
#
# 80: A=4, BARNARDO=3, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 81: A=4, BARNARDO=3, Courtier=6, Elsinore=2, FRANCISCO=2, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 82: A=4, BARNARDO=3, Courtier=6, Elsinore=2, FRANCISCO=3, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 83: A=4, BARNARDO=3, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=3, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 84: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=3, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 85: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=3, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 86: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 87: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 88: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 89: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 90: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 91: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 92: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 93: A=4, BARNARDO=4, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 94: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 95: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 96: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 97: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 98: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 99: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 100: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2
#
# 101: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 102: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 103: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=4, Francisco=2, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 104: A=4, BARNARDO=5, Barnardo=2, Courtier=6, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 105: A=4, BARNARDO=5, Barnardo=2, Courtier=5, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 106: A=4, BARNARDO=5, Barnardo=2, Courtier=5, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 107: A=4, BARNARDO=5, Barnardo=2, Courtier=4, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 108: A=4, BARNARDO=5, Barnardo=2, Courtier=4, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 109: A=4, BARNARDO=5, Barnardo=2, Courtier=3, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, and=3, the=2, to=2
#
# 110: A=4, BARNARDO=5, Barnardo=2, Courtier=3, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 111: A=4, BARNARDO=5, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 112: A=4, BARNARDO=5, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, Officer=2, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 113: A=4, BARNARDO=5, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=2, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 114: A=4, BARNARDO=4, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 115: A=4, BARNARDO=4, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 116: A=4, BARNARDO=4, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 117: A=4, BARNARDO=4, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 118: A=4, BARNARDO=4, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 119: A=4, BARNARDO=5, Barnardo=2, Courtier=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 120: A=4, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 121: A=4, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 122: A=4, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, to=2
#
# 123: A=4, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 124: A=4, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=4, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 125: A=4, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 126: A=3, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 127: A=3, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 128: A=3, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 129: A=2, BARNARDO=5, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 130: A=2, BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 131: A=2, BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 132: A=2, BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 133: A=2, BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 134: A=2, BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2
#
# 135: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, you=2
#
# 136: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, you=2
#
# 137: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, you=2
#
# 138: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, you=2
#
# 139: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=4, the=2, you=2
#
# 140: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=4, the=2, you=2
#
# 141: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=4, the=2, you=2
#
# 142: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=4, the=2, you=2
#
# 143: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=4, the=2, you=2
#
# 144: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=4, the=2, you=2
#
# 145: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, you=2
#
# 146: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, SCENE=2, Tis=2, and=3, the=2, you=2
#
# 147: BARNARDO=6, Barnardo=2, Elsinore=2, FRANCISCO=5, Francisco=2, I=3, Tis=2, and=3, the=2, you=2
#
# 148: BARNARDO=6, Barnardo=2, FRANCISCO=5, Francisco=2, I=3, Tis=2, and=3, the=2, you=2
#
# 149: BARNARDO=6, Barnardo=2, FRANCISCO=5, Francisco=2, I=3, Tis=2, and=3, the=2, you=2
